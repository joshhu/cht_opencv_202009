# %% [markdown]
# # Bitwise And
#
# 需要上傳`lena.bmp`灰階圖

# %%
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
print(cv2.__version__)

# %%
a=np.random.randint(0,255,(5,5),dtype=np.uint8)
b=np.zeros((5,5),dtype=np.uint8)
b[0:3,0:3]=255
b[4,4]=255
c=cv2.bitwise_and(a,b)
print("a=\n",a)
print("b=\n",b)
print("c=\n",c)

# %%
a = cv2.imread("lena.bmp",0)
b = np.zeros(a.shape,dtype=np.uint8)
b[100:400,200:400] = 255
b[100:500,100:200] = 255
c = cv2.bitwise_and(a,b)

cv2_imshow(a)
cv2_imshow(b)
cv2_imshow(c)

# %% [markdown]
# # 位平面分解

# %%
from google.colab.patches import cv2_imshow
import cv2
import numpy as np

lena=cv2.imread("lena.bmp",0)
cv2_imshow(lena)
r,c=lena.shape
x=np.zeros((r,c,8),dtype=np.uint8)
for i in range(8):
    x[:,:,i]=2**i
r=np.zeros((r,c,8),dtype=np.uint8)
for i in range(8):
    r[:,:,i]=cv2.bitwise_and(lena,x[:,:,i])
    mask=r[:,:,i]>0
    r[mask]=255
    cv2_imshow(r[:,:,i])
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7F93BAD797B8>
# <PIL.Image.Image image mode=L size=256x256 at 0x7F93BAD79748>
# <PIL.Image.Image image mode=L size=256x256 at 0x7F93BAD796A0>
# <PIL.Image.Image image mode=L size=256x256 at 0x7F93BAD79748>
# <PIL.Image.Image image mode=L size=256x256 at 0x7F93BAD796A0>
# <PIL.Image.Image image mode=L size=256x256 at 0x7F93BAD79748>
# <PIL.Image.Image image mode=L size=256x256 at 0x7F93BAD796A0>
# <PIL.Image.Image image mode=L size=256x256 at 0x7F93BAD79780>
# <PIL.Image.Image image mode=L size=256x256 at 0x7F93BAD79748>

# %% [markdown]
# # 影像加密及解密

# %%
from google.colab.patches import cv2_imshow
import cv2
import numpy as np

lena=cv2.imread("lena.bmp",0)
r,c=lena.shape
key=np.random.randint(0,256,size=[r,c],dtype=np.uint8)
encryption=cv2.bitwise_xor(lena,key)
decryption=cv2.bitwise_xor(encryption,key)
cv2_imshow(lena)
cv2_imshow(key)
cv2_imshow(encryption)
cv2_imshow(decryption)
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7F93BC5C3F98>
# <PIL.Image.Image image mode=L size=256x256 at 0x7F93BC5C3F28>
# <PIL.Image.Image image mode=L size=256x256 at 0x7F93BC5C3F60>
# <PIL.Image.Image image mode=L size=256x256 at 0x7F93BC5C3C88>
